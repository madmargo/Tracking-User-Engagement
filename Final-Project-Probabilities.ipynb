# %% [markdown]
# ### Import relevant libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Read .csv files

# %%
q2_2021 = pd.read_csv('q2-2021-total-students-watched.csv')
q2_2021
# Out:
#    count(student_id)
# 0              43274

# %%
q2_2022 = pd.read_csv('q2-2022-total-students-watched.csv')
q2_2022
# Out:
#    count(student_id)
# 0              42761

# %%
q2_both_years = pd.read_csv('q2-both-years-total-students-watched.csv')
q2_both_years
# Out:
#    students_both_years
# 0                  640

# %% [markdown]
# ### Find probability that a user watched in Q2 2021

# %%
probability_2021 = 43274 / 86035
probability_2021
# Out:
# 0.5029813448015342

# %% [markdown]
# ### Find probability that a user watched in Q2 2022

# %%
probability_2022 = 42761 / 86035
probability_2022
# Out:
# 0.4970186551984657

# %% [markdown]
# ### Find probability that a user watched in both Q2 2021 and Q2 2022

# %%
probability_both_years = 640 / 86035
probability_both_years
# Out:
# 0.007438833033067938

# %% [markdown]
# ### P(A union B) = P(A) * P(B)

# %%
print(probability_both_years == probability_2021 * probability_2022)
# Out:
# False

# %%
probability_2021 * probability_2022
# Out:
# 0.24999111158317433

# %% [markdown]
# ##### Since the probability of both years is not equal to the probability of 2021 times the probability of 2022, then the events are dependent

# %% [markdown]
# ### Find the probability that a user watched in both years, given they watched in Q2 2022

# %%
probability_both_years / probability_2022
# Out:
# 0.014966909099413018
